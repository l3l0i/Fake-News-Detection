# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

fake = pd.read_csv('/content/drive/MyDrive/data/Fake.csv')
real = pd.read_csv('/content/drive/MyDrive/data/True.csv')

fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake["label"] = 0
real["label"] = 1

# %%
import pandas as pd

data = pd.concat([fake, real])
data = data.sample(frac=1)

data.head()
# Out:
#                                                    title  \
# 2625   Russian envoy overheard saying he discussed ca...
# 15908  FBI UNDERCOVER Informant On Hillary’s 2010 Sal...
# 22644  HOLLYWOOD WITCHCRAFT: The Dark Side Revealed i...
# 2040    WATCH: McCain Scorches His Own Party’s Sham ‘...
# 18521  France's Macron backs Spain's constitutional u...
#
#                                                     text          subject  \
# 2625   WASHINGTON (Reuters) - Russia’s ambassador to ...     politicsNews
# 15908  The FBI informant who went undercover to look ...  Government News
# 22644  Jay Dyer 21st Century WireJamie Hanshaw, autho...          US_News
# 2040   Arizona Senator John McCain seems to be the lo...             News
# 18521  PARIS (Reuters) - French President Emmanuel Ma...        worldnews
#
#                    date  label
# 2625     July 21, 2017       1
# 15908      Nov 17, 2017      0
# 22644     March 5, 2016      0
# 2040     March 23, 2017      0
# 18521  October 2, 2017       1

# %%
X = data["text"]
y = data["label"]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)

X_vec = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(
    X_vec,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

predictions = model.predict(X_test)

accuracy = accuracy_score(y_test,predictions)

print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9897550111358575

# %%
news = ["Scientists discovered a miracle cure for cancer in one day"]

news_vec = vectorizer.transform(news)

prediction = model.predict(news_vec)

print(prediction)
# Out:
# [0]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test,predictions)

sns.heatmap(cm,annot=True,fmt='d')

plt.show()

# %%
import joblib

joblib.dump(model,"fake_news_model.pkl")
# Out:
# ['fake_news_model.pkl']
